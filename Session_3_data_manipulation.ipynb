# %%
import pandas as pd

# %%
df=pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
print(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB
# None

# %% [markdown]
# filtering

# %%
filtered_df=df[df['housing_median_age']>25]

# %% [markdown]
# sort

# %%
Sorted_df= filtered_df.sort_values(by='housing_median_age')

# %%
print(Sorted_df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12301    -121.49     38.47                26.0       6121.0          1185.0
# 3173     -117.84     33.78                26.0       2577.0           434.0
# 1159     -117.12     32.58                26.0       1360.0           309.0
# 10780    -120.68     35.26                26.0       1704.0           315.0
# 3175     -117.84     33.77                26.0       3350.0           581.0
# ...          ...       ...                 ...          ...             ...
# 6363     -118.26     34.11                52.0       1740.0           402.0
# 6362     -118.26     34.12                52.0       1942.0           476.0
# 6361     -118.26     34.12                52.0       2290.0           520.0
# 6373     -118.26     34.07                52.0        830.0           200.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 12301      4224.0      1105.0         2.3496             68000.0
# 3173       1086.0       432.0         4.6125            229200.0
# 1159        869.0       328.0         3.0217            131600.0
# 10780       918.0       310.0         3.2464            208000.0
# 3175       1314.0       550.0         3.5195            249100.0
# ...           ...         ...            ...                 ...
# 6363        749.0       335.0         3.5673            270700.0
# 6362       1375.0       477.0         2.7348            209100.0
# 6361       1278.0       485.0         3.8393            238200.0
# 6373        701.0       189.0         2.7625            232100.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [9863 rows x 9 columns]

# %% [markdown]
# grouping and aggregationg

# %%
grouped= df.groupby('housing_median_age')
result=grouped['median_house_value'].mean()
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-dc03c17ea1ea> in <cell line: 1>()
# ----> 1 grouped= df.groupby('housing_median_age')
#       2 result=grouped['median_house_value'].mean()
#       3 print(result)
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df['longitude']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6f7d3b8852d2> in <cell line: 1>()
# ----> 1 df['longitude']
#
# NameError: name 'df' is not defined

# %%
df['longitude', 'latitude']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6ad40a97a228> in <cell line: 1>()
# ----> 1 df['longitude', 'latitude']
#
# NameError: name 'df' is not defined

# %%
df.loc[2]
# Out:
# longitude              -114.5600
# latitude                 33.6900
# housing_median_age       17.0000
# total_rooms             720.0000
# total_bedrooms          174.0000
# population              333.0000
# households              117.0000
# median_income             1.6509
# median_house_value    85700.0000
# Name: 2, dtype: float64

# %%
df.iloc[0]
# Out:
# longitude              -114.3100
# latitude                 34.1900
# housing_median_age       15.0000
# total_rooms            5612.0000
# total_bedrooms         1283.0000
# population             1015.0000
# households              472.0000
# median_income             1.4936
# median_house_value    66900.0000
# Name: 0, dtype: float64

# %% [markdown]
# filtering-

# %%
df.rename(columns={'housing_median_age': 'age'}, inplace=True)
df.head()
# Out:
#    longitude  latitude   age  total_rooms  total_bedrooms  population  \
# 0    -114.31     34.19  15.0       5612.0          1283.0      1015.0
# 1    -114.47     34.40  19.0       7650.0          1901.0      1129.0
# 2    -114.56     33.69  17.0        720.0           174.0       333.0
# 3    -114.57     33.64  14.0       1501.0           337.0       515.0
# 4    -114.57     33.57  20.0       1454.0           326.0       624.0
#
#    households  median_income  median_house_value
# 0       472.0         1.4936             66900.0
# 1       463.0         1.8200             80100.0
# 2       117.0         1.6509             85700.0
# 3       226.0         3.1917             73400.0
# 4       262.0         1.9250             65500.0

# %% [markdown]
# Data inspections

# %%
df.head()
# Out:
#    longitude  latitude   age  total_rooms  total_bedrooms  population  \
# 0    -114.31     34.19  15.0       5612.0          1283.0      1015.0
# 1    -114.47     34.40  19.0       7650.0          1901.0      1129.0
# 2    -114.56     33.69  17.0        720.0           174.0       333.0
# 3    -114.57     33.64  14.0       1501.0           337.0       515.0
# 4    -114.57     33.57  20.0       1454.0           326.0       624.0
#
#    households  median_income  median_house_value
# 0       472.0         1.4936             66900.0
# 1       463.0         1.8200             80100.0
# 2       117.0         1.6509             85700.0
# 3       226.0         3.1917             73400.0
# 4       262.0         1.9250             65500.0

# %% [markdown]
# # New Section

# %%
df.describe()
# Out:
#           longitude      latitude           age   total_rooms  total_bedrooms  \
# count  17000.000000  17000.000000  17000.000000  17000.000000    17000.000000
# mean    -119.562108     35.625225     28.589353   2643.664412      539.410824
# std        2.005166      2.137340     12.586937   2179.947071      421.499452
# min     -124.350000     32.540000      1.000000      2.000000        1.000000
# 25%     -121.790000     33.930000     18.000000   1462.000000      297.000000
# 50%     -118.490000     34.250000     29.000000   2127.000000      434.000000
# 75%     -118.000000     37.720000     37.000000   3151.250000      648.250000
# max     -114.310000     41.950000     52.000000  37937.000000     6445.000000
#
#          population    households  median_income  median_house_value
# count  17000.000000  17000.000000   17000.000000        17000.000000
# mean    1429.573941    501.221941       3.883578       207300.912353
# std     1147.852959    384.520841       1.908157       115983.764387
# min        3.000000      1.000000       0.499900        14999.000000
# 25%      790.000000    282.000000       2.566375       119400.000000
# 50%     1167.000000    409.000000       3.544600       180400.000000
# 75%     1721.000000    605.250000       4.767000       265000.000000
# max    35682.000000   6082.000000      15.000100       500001.000000

# %%
df.isnull()
# Out:
#        longitude  latitude    age  total_rooms  total_bedrooms  population  \
# 0          False     False  False        False           False       False
# 1          False     False  False        False           False       False
# 2          False     False  False        False           False       False
# 3          False     False  False        False           False       False
# 4          False     False  False        False           False       False
# ...          ...       ...    ...          ...             ...         ...
# 16995      False     False  False        False           False       False
# 16996      False     False  False        False           False       False
# 16997      False     False  False        False           False       False
# 16998      False     False  False        False           False       False
# 16999      False     False  False        False           False       False
#
#        households  median_income  median_house_value
# 0           False          False               False
# 1           False          False               False
# 2           False          False               False
# 3           False          False               False
# 4           False          False               False
# ...           ...            ...                 ...
# 16995       False          False               False
# 16996       False          False               False
# 16997       False          False               False
# 16998       False          False               False
# 16999       False          False               False
#
# [17000 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   age                 17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %% [markdown]
# unuveriete analysis

# %%
import matplotlib.pyplot as plt

# %%
df['population'].hist()
plt.xlabel('population')
plt.ylabel('count')
plt.title('histogram')
# Out:
# Text(0.5, 1.0, 'histogram')

# %%
import seaborn as sns

# %%
sns.boxenplot(x=df['population'])
plt.title('boxplot')
# Out:
# Text(0.5, 1.0, 'boxplot')

# %%
plt.scatter(df['population'], df['median_house_value'])

# %% [markdown]
# heat map

# %%
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# LISTS in python

# %%
li=['learning', "python", "is", "fun", True]
print(li)
type(li)
# Out:
# ['learning', 'python', 'is', 'fun', True]
# list

# %%
li=list(('learning', "python", "is", "fun", True))
print(li)
type(li)
li.append('new')
print(li)
li.remove('new')
print(li)
l2= [1,2,3,4,5]
li.extend(l2)
print(li)
# Out:
# ['learning', 'python', 'is', 'fun', True]
# ['learning', 'python', 'is', 'fun', True, 'new']
# ['learning', 'python', 'is', 'fun', True]
# ['learning', 'python', 'is', 'fun', True, 1, 2, 3, 4, 5]

# %%
l3= [1,2,3,4,5]
print(l3)
type(l3)
print(sum(l3))
print(min(l3))
print(max(l3))

range(1,10)
# Out:
# [1, 2, 3, 4, 5]
# 15
# 1
# 5
# range(1, 10)

# %%
import numpy as np
import pandas as pd
pd.read_csv('/content/sample_data/california_housing_train.csv')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %%
import pandas as pd
pd.read_csv('/content/sample_data/california_housing_train.csv')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
pd.read_csv('/content/sample_data/california_housing_train.csv')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('/content/sample_data/california_housing_test.csv')
df.shape
# Out:
# (3000, 9)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
#dealing with missing values
print(df.isnull().sum()) #display the number of null values for each field
#check whether or not there are ANY null values in the data frame
print("dataframe has null values?", df.isnull().values.any())
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64
# dataframe has null values? False

# %%
#Split data into feature(x) and response (y)
x=df.drop('median_house_value', axis=1)
y=df['median_house_value']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7184009018a4> in <cell line: 2>()
#       1 #Split data into feature(x) and response (y)
# ----> 2 x=df.drop('median_house_value', axis=1)
#       3 y=df['median_house_value']
#
# NameError: name 'df' is not defined

# %%
# prompt: create a packet sniffer

# !pip install scapy

import scapy.all as scapy

def sniff_packets(interface="eth0", count=10):
  """Sniffs packets on the specified interface and prints basic information.

  Args:
    interface: The network interface to sniff on (default: eth0).  You may need to change this
               to your correct network interface name (e.g., wlan0, en0).
    count: The number of packets to capture (default: 10).
  """

  try:
    packets = scapy.sniff(iface=interface, count=count, store=True)  # Capture packets
    for packet in packets:
      # Extract source and destination IP addresses
      src_ip = packet[scapy.IP].src if scapy.IP in packet else "N/A"
      dst_ip = packet[scapy.IP].dst if scapy.IP in packet else "N/A"

      # Extract source and destination ports (if TCP/UDP)
      if scapy.TCP in packet:
        src_port = packet[scapy.TCP].sport
        dst_port = packet[scapy.TCP].dport
        protocol = "TCP"
      elif scapy.UDP in packet:
        src_port = packet[scapy.UDP].sport
        dst_port = packet[scapy.UDP].dport
        protocol = "UDP"
      else:
        src_port = "N/A"
        dst_port = "N/A"
        protocol = "Other"

      print(f"Source IP: {src_ip}, Source Port: {src_port}")
      print(f"Destination IP: {dst_ip}, Destination Port: {dst_port}")
      print(f"Protocol: {protocol}")
      print("-" * 20)

  except PermissionError:
    print("Permission denied.  You may need root privileges to capture packets.")
  except OSError:
    print(f"Interface '{interface}' not found or not available.")


if __name__ == "__main__":
  # Change "wlan0" to your network interface if necessary!
  sniff_packets(interface="wlan0") # Might need to change to eth0 or your wireless interface
# Out:
# Collecting scapy
#   Downloading scapy-2.6.1-py3-none-any.whl.metadata (5.6 kB)
# Downloading scapy-2.6.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 21.3 MB/s eta 0:00:00
# Installing collected packages: scapy
# Successfully installed scapy-2.6.1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-f08e7179ce0c> in <cell line: 0>()
#      48 if __name__ == "__main__":
#      49   # Change "wlan0" to your network interface if necessary!
# ---> 50   sniff_packets(interface="wlan0") # Might need to change to eth0 or your wireless interface
#
# <ipython-input-1-f08e7179ce0c> in sniff_packets(interface, count)
#      15
#      16   try:
# ---> 17     packets = scapy.sniff(iface=interface, count=count, store=True)  # Capture packets
#      18     for packet in packets:
#      19       # Extract source and destination IP addresses
#
# /usr/local/lib/python3.11/dist-packages/scapy/sendrecv.py in sniff(*args, **kwargs)
#    1422     # type: (*Any, **Any) -> PacketList
#    1423     sniffer = AsyncSniffer()
# -> 1424     sniffer._run(*args, **kwargs)
#    1425     return cast(PacketList, sniffer.results)
#    1426
#
# /usr/local/lib/python3.11/dist-packages/scapy/sendrecv.py in _run(self, count, store, offline, quiet, prn, lfilter, L2socket, timeout, opened_socket, stop_filter, iface, started_callback, session, chainCC, **karg)
#    1271             else:
#    1272                 iface = iface or conf.iface
# -> 1273                 sniff_sockets[_RL2(iface)(type=ETH_P_ALL, iface=iface,
#    1274                                           **karg)] = iface
#    1275
#
# /usr/local/lib/python3.11/dist-packages/scapy/sendrecv.py in <lambda>(i)
#    1256         if not sniff_sockets or iface is not None:
#    1257             # The _RL2 function resolves the L2socket of an iface
# -> 1258             _RL2 = lambda i: L2socket or resolve_iface(i).l2listen()  # type: Callable[[_GlobInterfaceType], Callable[..., SuperSocket]]  # noqa: E501
#    1259             if isinstance(iface, list):
#    1260                 sniff_sockets.update(
#
# /usr/local/lib/python3.11/dist-packages/scapy/interfaces.py in resolve_iface(dev, retry)
#     432     # Nothing found yet. Reload to detect if it was added recently
#     433     conf.ifaces.reload()
# --> 434     return resolve_iface(dev, retry=False)
#     435
#     436
#
# /usr/local/lib/python3.11/dist-packages/scapy/interfaces.py in resolve_iface(dev, retry)
#     429             pass
#     430     if not retry:
# --> 431         raise ValueError("Interface '%s' not found !" % dev)
#     432     # Nothing found yet. Reload to detect if it was added recently
#     433     conf.ifaces.reload()
#
# ValueError: Interface 'wlan0' not found !
